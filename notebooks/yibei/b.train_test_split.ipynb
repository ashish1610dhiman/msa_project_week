# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
sell = pd.read_excel('../data/Hackathon Data.xlsx')

# %%
sell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846632 entries, 0 to 846631
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Encoded_SKU_ID    846632 non-null  int64
#  1   SALES_DATE        846632 non-null  datetime64[ns]
#  2   SUBCLASS_NAME     846632 non-null  object
#  3   CLASS_NAME        846632 non-null  object
#  4   ML_NAME           846632 non-null  object
#  5   CATEGORY_NAME     846632 non-null  object
#  6   RETAIL_PRICE      846632 non-null  float64
#  7   PROMO_PRICE       846632 non-null  object
#  8   COMPETITOR_PRICE  846632 non-null  object
#  9   Inventory         846632 non-null  object
#  10  DAILY_UNITS       846632 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(7)
# memory usage: 71.1+ MB

# %%
sell[sell['Encoded_SKU_ID']==1].sort_values('SALES_DATE', ascending = False).head(7)
# Out:
#         Encoded_SKU_ID SALES_DATE      SUBCLASS_NAME           CLASS_NAME  \
# 411277               1 2022-07-31  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 795518               1 2022-07-30  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 394968               1 2022-07-29  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 680505               1 2022-07-28  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 225673               1 2022-07-27  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 607613               1 2022-07-26  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
# 82792                1 2022-07-25  MISC CAMERA ACCES  DIGITAL CAMERA ACCY
#
#                     ML_NAME         CATEGORY_NAME  RETAIL_PRICE PROMO_PRICE  \
# 411277  ML - DI Accessories  VP - Digital Imaging         89.99           ?
# 795518  ML - DI Accessories  VP - Digital Imaging         89.99           ?
# 394968  ML - DI Accessories  VP - Digital Imaging         89.99           ?
# ...

# %%
sell[sell['Encoded_SKU_ID']==2].sort_values('SALES_DATE', ascending = False).head(7)
# Out:
#         Encoded_SKU_ID SALES_DATE     SUBCLASS_NAME           CLASS_NAME  \
# 663520               2 2022-07-31  CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 171873               2 2022-07-30  CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 456670               2 2022-07-29  CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 814372               2 2022-07-28  CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 414051               2 2022-07-27  CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 714826               2 2022-07-26  CAMERA BATTERIES  DIGITAL CAMERA ACCY
# 268525               2 2022-07-25  CAMERA BATTERIES  DIGITAL CAMERA ACCY
#
#                     ML_NAME         CATEGORY_NAME  RETAIL_PRICE PROMO_PRICE  \
# 663520  ML - DI Accessories  VP - Digital Imaging         39.99           ?
# 171873  ML - DI Accessories  VP - Digital Imaging         39.99           ?
# 456670  ML - DI Accessories  VP - Digital Imaging         39.99           ?
# 814372  ML - DI Accessories  VP - Digital Imaging         39.99           ?
# ...
